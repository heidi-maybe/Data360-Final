# %% [markdown]
# # Data 360 Final

# %% [markdown]
# ### Final web scraping code.

# %% [markdown]
# Scraping data from IMDb's 100 most popular movies. Data scraped includes titles, release dates, watch time, MPAA rating, star rating, genres, and url to the movies page on IMDb.

# %%
import requests
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
from bs4 import BeautifulSoup
import pandas as pd


driver = webdriver.Safari()
driver.get("https://www.imdb.com/chart/moviemeter/?ref_=nv_mv_mpm")


last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    driver.find_element(By.TAG_NAME, "body").send_keys(Keys.END)
    time.sleep(2)
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height


soup = BeautifulSoup(driver.page_source, "html.parser")
driver.quit()

results = soup.find('ul', class_='ipc-metadata-list ipc-metadata-list--dividers-between sc-e22973a9-0 khSCXM compact-list-view ipc-metadata-list--base')
movie_elements = results.find_all('li', class_="ipc-metadata-list-summary-item")

# %%
movie = []

for movie_element in movie_elements:
    genre = []
    title_element = movie_element.find("h3").text.strip()
    
    descr_elements = movie_element.find_all("span", class_="sc-4b408797-8 iurwGb cli-title-metadata-item")
    star_element = movie_element.find("span", class_="ipc-rating-star--rating")
    star_element = star_element.text.strip() if star_element else None
    link_element = movie_element.find("a")["href"]
    movie_url = "https://www.imdb.com" + link_element

    release_element = descr_elements[0].text.strip() if len(descr_elements) > 0 else None
    time_element = descr_elements[1].text.strip() if len(descr_elements) > 1 else None
    movie_element = descr_elements[2].text.strip() if len(descr_elements) > 2 else None

    try:
        headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.0.0 Safari/537.36",}
        movie_page = requests.get(movie_url, headers=headers)
        movie_soup = BeautifulSoup(movie_page.content, "html.parser")

    
        genre_elements = movie_soup.find_all('a', class_="ipc-chip ipc-chip--on-baseAlt")
        for genre_element in genre_elements:
            genre_name = genre_element.find('span', class_="ipc-chip__text").text.strip()

            genre.append(genre_name)

    except:
        genre.append(None)
     
    movie.append([title_element, release_element, time_element, movie_element, star_element, genre, movie_url])
movie
# Out:
# [['Thunderbolts*',
#   '2025',
#   '2h 6m',
#   'PG-13',
#   '7.7',
#   ['Political Drama',
#    'Superhero',
#    'Action',
#    'Adventure',
#    'Crime',
#    'Drama',
#    'Fantasy',
#    'Sci-Fi'],
#   'https://www.imdb.com/title/tt20969586/?ref_=chtmvm_i_1'],
#  ['Sinners',
#   '2025',
#   '2h 17m',
#   'R',
#   '8.1',
#   ['Period Drama',
#    'Supernatural Horror',
#    'Vampire Horror',
#    'Action',
#    'Drama',
#    'Horror',
#    'Thriller'],
#   'https://www.imdb.com/title/tt31193180/?ref_=chtmvm_i_2'],
#  ['Havoc',
#   '2025',
#   '1h 47m',
#   'TV-MA',
#   '5.7',
#   ['Conspiracy Thriller',
#    'Drug Crime',
#    'Gun Fu',
#    'Martial Arts',
#    'One-Person Army Action',
#    'Suspense Mystery',
#    'Action',
#    'Crime',
#    'Drama',
#    'Mystery'],
#   'https://www.imdb.com/title/tt14123284/?ref_=chtmvm_i_3'],
#  ['Another Simple Favor',
#   '2025',
#   '2h',
#   'R',
#   '5.3',
#   ['Dark Comedy', 'Whodunnit', 'Comedy', 'Crime', 'Mystery', 'Thriller'],
#   'https://www.imdb.com/title/tt20214908/?ref_=chtmvm_i_4'],
#  ['The Accountant 2',
#   '2025',
#   '2h 12m',
#   'R',
#   '7.1',
#   ['Whodunnit', 'Action', 'Crime', 'Drama', 'Mystery', 'Thriller'],
#   'https://www.imdb.com/title/tt7068946/?ref_=chtmvm_i_5'],
#  ['Conclave',
#   '2024',
#   '2h',
#   'PG',
#   '7.4',
#   ['Conspiracy Thriller', 'Drama', 'Thriller'],
#   'https://www.imdb.com/title/tt20215234/?ref_=chtmvm_i_6'],
#  ['Exterritorial',
#   '2025',
#   '1h 49m',
#   'TV-MA',
#   '5.8',
#   ['Action', 'Mystery', 'Thriller'],
#   'https://www.imdb.com/title/tt30876483/?ref_=chtmvm_i_7'],
#  ["Now You See Me: Now You Don't",
#   '2025',
#   None,
#   None,
#   None,
#   ['Crime', 'Thriller'],
#   'https://www.imdb.com/title/tt4712810/?ref_=chtmvm_i_8'],
#  ['A Minecraft Movie',
#   '2025',
#   '1h 41m',
#   'PG',
#   '5.9',
#   ['Action Epic',
#    'Adventure Epic',
#    'Fantasy Epic',
#    'High-Concept Comedy',
#    'Quest',
#    'Slapstick',
#    'Survival',
#    'Action',
#    'Adventure',
#    'Comedy'],
#   'https://www.imdb.com/title/tt3566834/?ref_=chtmvm_i_9'],
#  ['Until Dawn',
#   '2025',
#   '1h 43m',
#   'R',
#   '6.0',
#   ['Psychological Drama',
#    'Psychological Horror',
#    'Slasher Horror',
#    'Splatter Horror',
#    'Supernatural Horror',
#    'Zombie Horror',
#    'Drama',
#    'Horror'],
#   'https://www.imdb.com/title/tt30955489/?ref_=chtmvm_i_10'],
#  ['Drop',
#   '2025',
#   '1h 35m',
#   'PG-13',
#   '6.2',
#   ['Whodunnit', 'Drama', 'Mystery', 'Thriller'],
#   'https://www.imdb.com/title/tt32149847/?ref_=chtmvm_i_11'],
#  ['The Smashing Machine',
#   '2025',
#   'R',
#   None,
#   None,
#   ['Action', 'Biography', 'Drama', 'Sport'],
#   'https://www.imdb.com/title/tt11214558/?ref_=chtmvm_i_12'],
#  ['Death of a Unicorn',
#   '2025',
#   '1h 47m',
#   'R',
#   '6.0',
#   ['Dark Comedy',
#    'Dark Fantasy',
#    'Monster Horror',
#    'Comedy',
#    'Fantasy',
#    'Horror',
#    'Thriller'],
#   'https://www.imdb.com/title/tt28443655/?ref_=chtmvm_i_13'],
#  ['A Simple Favor',
#   '2018',
#   '1h 57m',
#   'R',
#   '6.8',
#   ['Dark Comedy',
#    'Psychological Thriller',
#    'Comedy',
#    'Crime',
#    'Mystery',
#    'Thriller'],
#   'https://www.imdb.com/title/tt7040874/?ref_=chtmvm_i_14'],
#  ['Weapons',
#   '2025',
#   '2h 8m',
#   'R',
#   None,
#   ['Horror', 'Mystery'],
#   'https://www.imdb.com/title/tt26581740/?ref_=chtmvm_i_15'],
#  ['Warfare',
#   '2025',
#   '1h 35m',
#   'R',
#   '7.8',
#   ['Docudrama', 'War Epic', 'Action', 'Drama', 'War'],
#   'https://www.imdb.com/title/tt31434639/?ref_=chtmvm_i_16'],
#  ['The Accountant',
#   '2016',
#   '2h 8m',
#   'R',
#   '7.3',
#   ['Conspiracy Thriller',
#    'Martial Arts',
#    'One-Person Army Action',
#    'Action',
#    'Crime',
#    'Drama',
#    'Thriller'],
#   'https://www.imdb.com/title/tt2140479/?ref_=chtmvm_i_17'],
#  ['Snow White',
#   '2025',
#   '1h 49m',
#   'PG',
#   '1.6',
#   ['Fairy Tale',
#    'Feel-Good Romance',
#    'Adventure',
#    'Family',
#    'Fantasy',
#    'Musical',
#    'Romance'],
#   'https://www.imdb.com/title/tt6208148/?ref_=chtmvm_i_18'],
#  ['Companion',
#   '2025',
#   '1h 37m',
#   'R',
#   '6.9',
#   ['Artificial Intelligence',
#    'Dark Comedy',
#    'Psychological Thriller',
#    'Sci-Fi',
#    'Thriller'],
#   'https://www.imdb.com/title/tt26584495/?ref_=chtmvm_i_19'],
#  ['Raid 2',
#   '2025',
#   '2h 25m',
#   None,
#   '7.9',
#   ['Crime', 'Drama', 'Thriller'],
#   'https://www.imdb.com/title/tt28089700/?ref_=chtmvm_i_20'],
#  ['Predator: Badlands',
#   '2025',
#   None,
#   None,
#   None,
#   ['Alien Invasion', 'Sci-Fi'],
#   'https://www.imdb.com/title/tt31227572/?ref_=chtmvm_i_21'],
#  ['Black Bag',
#   '2025',
#   '1h 33m',
#   'R',
#   '6.8',
#   ['Spy', 'Drama', 'Mystery', 'Romance', 'Thriller'],
#   'https://www.imdb.com/title/tt30988739/?ref_=chtmvm_i_22'],
#  ['Ash',
#   '2025',
#   '1h 35m',
#   'R',
#   '4.7',
#   ['Alien Invasion',
#    'Monster Horror',
#    'Psychological Horror',
#    'Psychological Thriller',
#    'Space Sci-Fi',
#    'Survival',
#    'Horror',
#    'Sci-Fi',
#    'Thriller'],
#   'https://www.imdb.com/title/tt17489650/?ref_=chtmvm_i_23'],
#  ['Babygirl',
#   '2024',
#   '1h 54m',
#   'R',
#   '5.9',
#   ['Erotic Thriller', 'Workplace Drama', 'Drama', 'Romance', 'Thriller'],
#   'https://www.imdb.com/title/tt30057084/?ref_=chtmvm_i_24'],
#  ['The Amateur',
#   '2025',
#   '2h 2m',
#   'PG-13',
#   '6.7',
#   ['Spy', 'Action', 'Thriller'],
#   'https://www.imdb.com/title/tt0899043/?ref_=chtmvm_i_25'],
#  ['Mickey 17',
#   '2025',
#   '2h 17m',
#   'R',
#   '6.8',
#   ['Alien Invasion',
#    'Dark Comedy',
#    'Space Sci-Fi',
#    'Adventure',
#    'Comedy',
#    'Fantasy',
#    'Sci-Fi'],
#   'https://www.imdb.com/title/tt12299608/?ref_=chtmvm_i_26'],
#  ['Mission: Impossible - The Final Reckoning',
#   '2025',
#   '2h 49m',
#   'PG-13',
#   None,
#   ['Adventure Epic', 'Action', 'Adventure', 'Thriller'],
#   'https://www.imdb.com/title/tt9603208/?ref_=chtmvm_i_27'],
#  ['Star Wars: Episode III - Revenge of the Sith',
#   '2005',
#   '2h 20m',
#   'PG-13',
#   '7.6',
#   ['Action Epic',
#    'Adventure Epic',
#    'Dark Fantasy',
#    'Epic',
#    'Fantasy Epic',
#    'Sci-Fi Epic',
#    'Space Sci-Fi',
#    'Tragedy',
#    'Action',
#    'Adventure'],
#   'https://www.imdb.com/title/tt0121766/?ref_=chtmvm_i_28'],
#  ['Anora',
#   '2024',
#   '2h 19m',
#   'R',
#   '7.5',
#   ['Dark Comedy',
#    'Raunchy Comedy',
#    'Steamy Romance',
#    'Comedy',
#    'Drama',
#    'Romance'],
#   'https://www.imdb.com/title/tt28607951/?ref_=chtmvm_i_29'],
#  ['Final Destination: Bloodlines',
#   '2025',
#   '1h 50m',
#   'R',
#   None,
#   ['Slasher Horror', 'Splatter Horror', 'Supernatural Horror', 'Horror'],
#   'https://www.imdb.com/title/tt9619824/?ref_=chtmvm_i_30'],
#  ['Rust',
#   '2024',
#   '2h 19m',
#   'Not Rated',
#   '4.8',
#   ['Western'],
#   'https://www.imdb.com/title/tt11001074/?ref_=chtmvm_i_31'],
#  ['The Fantastic Four: First Steps',
#   '2025',
#   None,
#   None,
#   None,
#   ['Space Sci-Fi', 'Superhero', 'Action', 'Adventure', 'Sci-Fi'],
#   'https://www.imdb.com/title/tt10676052/?ref_=chtmvm_i_32'],
#  ['Freaky Tales',
#   '2024',
#   '1h 47m',
#   'R',
#   '6.3',
#   ['Action', 'Adventure', 'Comedy', 'Crime', 'Drama'],
#   'https://www.imdb.com/title/tt21942598/?ref_=chtmvm_i_33'],
#  ['The Four Seasons',
#   '1981',
#   '1h 47m',
#   'PG',
#   '6.8',
#   ['Comedy', 'Drama'],
#   'https://www.imdb.com/title/tt0082405/?ref_=chtmvm_i_34'],
#  ['Captain America: Brave New World',
#   '2025',
#   '1h 58m',
#   'PG-13',
#   '5.7',
#   ['Action Epic',
#    'Adventure Epic',
#    'Sci-Fi Epic',
#    'Superhero',
#    'Action',
#    'Adventure',
#    'Sci-Fi'],
#   'https://www.imdb.com/title/tt14513804/?ref_=chtmvm_i_35'],
#  ['A Working Man',
#   '2025',
#   '1h 56m',
#   'R',
#   '5.8',
#   ['Conspiracy Thriller', 'One-Person Army Action', 'Action', 'Thriller'],
#   'https://www.imdb.com/title/tt9150192/?ref_=chtmvm_i_36'],
#  ['A Complete Unknown',
#   '2024',
#   '2h 21m',
#   'R',
#   '7.4',
#   ['Docudrama',
#    'Period Drama',
#    'Showbiz Drama',
#    'Biography',
#    'Drama',
#    'Music'],
#   'https://www.imdb.com/title/tt11563598/?ref_=chtmvm_i_37'],
#  ['Gladiator II',
#   '2024',
#   '2h 28m',
#   'R',
#   '6.5',
#   ['Action Epic',
#    'Adventure Epic',
#    'Epic',
#    'Period Drama',
#    'Sword & Sandal',
#    'Action',
#    'Adventure',
#    'Drama'],
#   'https://www.imdb.com/title/tt9218128/?ref_=chtmvm_i_38'],
#  ['Nosferatu',
#   '2024',
#   '2h 12m',
#   'R',
#   '7.2',
#   ['Dark Fantasy',
#    'Supernatural Horror',
#    'Vampire Horror',
#    'Fantasy',
#    'Horror',
#    'Mystery'],
#   'https://www.imdb.com/title/tt5040012/?ref_=chtmvm_i_39'],
#  ['Avengers: Doomsday',
#   '2026',
#   None,
#   None,
#   None,
#   ['Action Epic',
#    'Adventure Epic',
#    'Sci-Fi Epic',
#    'Superhero',
#    'Action',
#    'Adventure',
#    'Sci-Fi'],
#   'https://www.imdb.com/title/tt21357150/?ref_=chtmvm_i_40'],
#  ['The Substance',
#   '2024',
#   '2h 21m',
#   'R',
#   '7.3',
#   ['Body Horror',
#    'Dark Comedy',
#    'Monster Horror',
#    'Psychological Horror',
#    'Showbiz Drama',
#    'Drama',
#    'Horror',
#    'Sci-Fi'],
#   'https://www.imdb.com/title/tt17526714/?ref_=chtmvm_i_41'],
#  ['Bullet Train Explosion',
#   '2025',
#   '2h 14m',
#   'TV-14',
#   '6.3',
#   ['Disaster', 'Action', 'Crime', 'Drama', 'Thriller'],
#   'https://www.imdb.com/title/tt33452974/?ref_=chtmvm_i_42'],
#  ['iHostage',
#   '2025',
#   '1h 40m',
#   'TV-MA',
#   '5.7',
#   ['Crime', 'Drama', 'Thriller'],
#   'https://www.imdb.com/title/tt31181421/?ref_=chtmvm_i_43'],
#  ['Neighborhood Watch',
#   '2025',
#   '1h 32m',
#   'R',
#   '6.1',
#   ['Crime', 'Thriller'],
#   'https://www.imdb.com/title/tt1714918/?ref_=chtmvm_i_44'],
#  ['Heretic',
#   '2024',
#   '1h 51m',
#   'R',
#   '7.0',
#   ['Psychological Horror', 'Psychological Thriller', 'Horror', 'Thriller'],
#   'https://www.imdb.com/title/tt28015403/?ref_=chtmvm_i_45'],
#  ['The Monkey',
#   '2025',
#   '1h 38m',
#   'R',
#   '6.0',
#   ['Dark Comedy', 'Splatter Horror', 'Horror'],
#   'https://www.imdb.com/title/tt27714946/?ref_=chtmvm_i_46'],
#  ['Superman',
#   '2025',
#   None,
#   None,
#   None,
#   ['Superhero', 'Action', 'Adventure', 'Fantasy', 'Sci-Fi'],
#   'https://www.imdb.com/title/tt5950044/?ref_=chtmvm_i_47'],
#  ['The Surfer',
#   '2024',
#   '1h 40m',
#   'R',
#   '6.5',
#   ['Psychological Thriller', 'Thriller'],
#   'https://www.imdb.com/title/tt27813235/?ref_=chtmvm_i_48'],
#  ['Locked',
#   '2025',
#   '1h 35m',
#   'R',
#   '5.8',
#   ['Psychological Thriller', 'Thriller'],
#   'https://www.imdb.com/title/tt26671996/?ref_=chtmvm_i_49'],
#  ['Winter Spring Summer or Fall',
#   '2024',
#   '1h 37m',
#   'R',
#   '6.1',
#   ['Coming-of-Age', 'Drama', 'Romance'],
#   'https://www.imdb.com/title/tt24515124/?ref_=chtmvm_i_50'],
#  ['The Gorge',
#   '2025',
#   '2h 7m',
#   'PG-13',
#   '6.7',
#   ['Dark Romance',
#    'Monster Horror',
#    'Survival',
#    'Action',
#    'Adventure',
#    'Horror',
#    'Romance',
#    'Sci-Fi'],
#   'https://www.imdb.com/title/tt13654226/?ref_=chtmvm_i_51'],
#  ['Gladiator',
#   '2000',
#   '2h 35m',
#   'R',
#   '8.5',
#   ['Action Epic',
#    'Adventure Epic',
#    'Epic',
#    'Period Drama',
#    'Sword & Sandal',
#    'Action',
#    'Adventure',
#    'Drama'],
#   'https://www.imdb.com/title/tt0172495/?ref_=chtmvm_i_52'],
#  ['Novocaine',
#   '2025',
#   '1h 50m',
#   'R',
#   '6.5',
#   ['Dark Comedy',
#    'One-Person Army Action',
#    'Superhero',
#    'Action',
#    'Comedy',
#    'Thriller'],
#   'https://www.imdb.com/title/tt29603959/?ref_=chtmvm_i_53'],
#  ['Pride & Prejudice',
#   '2005',
#   '2h 9m',
#   'PG',
#   '7.8',
#   ['Costume Drama',
#    'Feel-Good Romance',
#    'Period Drama',
#    'Romantic Epic',
#    'Drama',
#    'Romance'],
#   'https://www.imdb.com/title/tt0414387/?ref_=chtmvm_i_54'],
#  ['The Life List',
#   '2025',
#   '2h 3m',
#   'PG-13',
#   '6.8',
#   ['Feel-Good Romance', 'Romantic Comedy', 'Comedy', 'Drama', 'Romance'],
#   'https://www.imdb.com/title/tt2172954/?ref_=chtmvm_i_55'],
#  ['Rogue One: A Star Wars Story',
#   '2016',
#   '2h 13m',
#   'PG-13',
#   '7.8',
#   ['Action Epic',
#    'Adventure Epic',
#    'Sci-Fi Epic',
#    'Space Sci-Fi',
#    'Tragedy',
#    'Action',
#    'Adventure',
#    'Sci-Fi'],
#   'https://www.imdb.com/title/tt3748528/?ref_=chtmvm_i_56'],
#  ['28 Years Later',
#   '2025',
#   '2h 6m',
#   None,
#   None,
#   ['Zombie Horror', 'Horror', 'Thriller'],
#   'https://www.imdb.com/title/tt10548174/?ref_=chtmvm_i_57'],
#  ['Together',
#   '2025',
#   '1h 42m',
#   'R',
#   '6.9',
#   ['Body Horror', 'Psychological Horror', 'Horror', 'Sci-Fi'],
#   'https://www.imdb.com/title/tt31184028/?ref_=chtmvm_i_58'],
#  ['The Shawshank Redemption',
#   '1994',
#   '2h 22m',
#   'R',
#   '9.3',
#   ['Epic', 'Period Drama', 'Prison Drama', 'Drama'],
#   'https://www.imdb.com/title/tt0111161/?ref_=chtmvm_i_59'],
#  ['G20',
#   '2025',
#   '1h 48m',
#   'R',
#   '5.1',
#   ['Action', 'Thriller'],
#   'https://www.imdb.com/title/tt23476986/?ref_=chtmvm_i_60'],
#  ['Jewel Thief: The Heist Begins',
#   '2025',
#   '1h 56m',
#   None,
#   '4.1',
#   ['Action', 'Adventure', 'Thriller'],
#   'https://www.imdb.com/title/tt27843798/?ref_=chtmvm_i_61'],
#  ['The Order',
#   '2024',
#   '1h 56m',
#   'R',
#   '6.8',
#   ['Heist', 'True Crime', 'Crime', 'Drama', 'Thriller'],
#   'https://www.imdb.com/title/tt26625693/?ref_=chtmvm_i_62'],
#  ['Last Breath',
#   '2025',
#   '1h 33m',
#   'PG-13',
#   '6.6',
#   ['Sea Adventure', 'Drama', 'Thriller'],
#   'https://www.imdb.com/title/tt14403504/?ref_=chtmvm_i_63'],
#  ['The Electric State',
#   '2025',
#   '2h 5m',
#   'PG-13',
#   '5.9',
#   ['Action Epic',
#    'Adventure Epic',
#    'Artificial Intelligence',
#    'Dystopian Sci-Fi',
#    'Epic',
#    'Quest',
#    'Sci-Fi Epic',
#    'Urban Adventure',
#    'Action',
#    'Adventure'],
#   'https://www.imdb.com/title/tt7766378/?ref_=chtmvm_i_64'],
#  ['Lilo & Stitch',
#   '2025',
#   '1h 48m',
#   'PG',
#   None,
#   ['Alien Invasion',
#    'Buddy Comedy',
#    'Sci-Fi Epic',
#    'Space Sci-Fi',
#    'Action',
#    'Adventure',
#    'Comedy',
#    'Drama',
#    'Family',
#    'Fantasy'],
#   'https://www.imdb.com/title/tt11655566/?ref_=chtmvm_i_65'],
#  ['Now You See Me',
#   '2013',
#   '1h 55m',
#   'PG-13',
#   '7.2',
#   ['Caper', 'Heist', 'Crime', 'Mystery', 'Thriller'],
#   'https://www.imdb.com/title/tt1670345/?ref_=chtmvm_i_66'],
#  ['Den of Thieves: Pantera',
#   '2025',
#   '2h 24m',
#   'R',
#   '6.3',
#   ['Heist', 'Action', 'Crime', 'Drama', 'Thriller'],
#   'https://www.imdb.com/title/tt8008948/?ref_=chtmvm_i_67'],
#  ['How to Train Your Dragon',
#   '2025',
#   '2h 5m',
#   'PG',
#   None,
#   ['Sword & Sorcery',
#    'Teen Adventure',
#    'Teen Fantasy',
#    'Action',
#    'Adventure',
#    'Comedy',
#    'Drama',
#    'Family',
#    'Fantasy'],
#   'https://www.imdb.com/title/tt26743210/?ref_=chtmvm_i_68'],
#  ['Oppenheimer',
#   '2023',
#   '3h',
#   'R',
#   '8.3',
#   ['Docudrama',
#    'Epic',
#    'Historical Epic',
#    'Period Drama',
#    'Psychological Drama',
#    'Biography',
#    'Drama',
#    'History'],
#   'https://www.imdb.com/title/tt15398776/?ref_=chtmvm_i_69'],
#  ['The Friend',
#   '2024',
#   '1h 59m',
#   'R',
#   '6.5',
#   ['Drama'],
#   'https://www.imdb.com/title/tt18108824/?ref_=chtmvm_i_70'],
#  ['Wicked',
#   '2024',
#   '2h 40m',
#   'PG',
#   '7.5',
#   ['Fairy Tale', 'Pop Musical', 'Fantasy', 'Musical', 'Romance'],
#   'https://www.imdb.com/title/tt1262426/?ref_=chtmvm_i_71'],
#  ['The King of Kings',
#   '2025',
#   '1h 43m',
#   'PG',
#   '7.4',
#   ['Computer Animation', 'Animation', 'Family'],
#   'https://www.imdb.com/title/tt7967302/?ref_=chtmvm_i_72'],
#  ['The Brutalist',
#   '2024',
#   '3h 36m',
#   'R',
#   '7.4',
#   ['Epic', 'Drama'],
#   'https://www.imdb.com/title/tt8999762/?ref_=chtmvm_i_73'],
#  ['Cleaner',
#   '2025',
#   '1h 37m',
#   'R',
#   '5.0',
#   ['One-Person Army Action', 'Action', 'Drama', 'Thriller'],
#   'https://www.imdb.com/title/tt27812086/?ref_=chtmvm_i_74'],
#  ['Interstellar',
#   '2014',
#   '2h 49m',
#   'PG-13',
#   '8.7',
#   ['Adventure Epic',
#    'Epic',
#    'Quest',
#    'Sci-Fi Epic',
#    'Space Sci-Fi',
#    'Time Travel',
#    'Adventure',
#    'Drama',
#    'Sci-Fi'],
#   'https://www.imdb.com/title/tt0816692/?ref_=chtmvm_i_75'],
#  ['The Godfather',
#   '1972',
#   '2h 55m',
#   'R',
#   '9.2',
#   ['Epic', 'Gangster', 'Tragedy', 'Crime', 'Drama'],
#   'https://www.imdb.com/title/tt0068646/?ref_=chtmvm_i_76'],
#  ['I Know What You Did Last Summer',
#   '2025',
#   None,
#   None,
#   None,
#   ['Slasher Horror', 'Horror'],
#   'https://www.imdb.com/title/tt4045450/?ref_=chtmvm_i_77'],
#  ['Barbarian',
#   '2022',
#   '1h 42m',
#   'R',
#   '7.0',
#   ['Psychological Horror',
#    'Psychological Thriller',
#    'Suspense Mystery',
#    'Horror',
#    'Mystery',
#    'Thriller'],
#   'https://www.imdb.com/title/tt15791034/?ref_=chtmvm_i_78'],
#  ['Black Widow',
#   '2021',
#   '2h 14m',
#   'PG-13',
#   '6.6',
#   ['Spy', 'Superhero', 'Action', 'Adventure', 'Sci-Fi'],
#   'https://www.imdb.com/title/tt3480822/?ref_=chtmvm_i_79'],
#  ['The Penguin Lessons',
#   '2024',
#   '1h 51m',
#   'PG-13',
#   '7.1',
#   ['Drama'],
#   'https://www.imdb.com/title/tt26677014/?ref_=chtmvm_i_80'],
#  ['From the World of John Wick: Ballerina',
#   '2025',
#   '2h 5m',
#   None,
#   None,
#   ['One-Person Army Action', 'Action', 'Thriller'],
#   'https://www.imdb.com/title/tt7181546/?ref_=chtmvm_i_81'],
#  ['Twisters',
#   '2024',
#   '2h 2m',
#   'PG-13',
#   '6.5',
#   ['Disaster', 'Action', 'Adventure', 'Thriller'],
#   'https://www.imdb.com/title/tt12584954/?ref_=chtmvm_i_82'],
#  ['The Two Popes',
#   '2019',
#   '2h 5m',
#   'PG-13',
#   '7.6',
#   ['Docudrama', 'Biography', 'Comedy', 'Drama'],
#   'https://www.imdb.com/title/tt8404614/?ref_=chtmvm_i_83'],
#  ['Once Upon a Time... in Hollywood',
#   '2019',
#   '2h 41m',
#   'R',
#   '7.6',
#   ['Period Drama', 'Showbiz Drama', 'Comedy', 'Drama'],
#   'https://www.imdb.com/title/tt7131622/?ref_=chtmvm_i_84'],
#  ['Top Gun: Maverick',
#   '2022',
#   '2h 10m',
#   'PG-13',
#   '8.2',
#   ['Action Epic', 'Epic', 'Action', 'Drama'],
#   'https://www.imdb.com/title/tt1745960/?ref_=chtmvm_i_85'],
#  ['Mufasa: The Lion King',
#   '2024',
#   '1h 58m',
#   'PG',
#   '6.6',
#   ['Animal Adventure',
#    'Computer Animation',
#    'Adventure',
#    'Animation',
#    'Drama',
#    'Family',
#    'Fantasy',
#    'Musical'],
#   'https://www.imdb.com/title/tt13186482/?ref_=chtmvm_i_86'],
#  ['The Hunger Games: Sunrise on the Reaping',
#   '2026',
#   None,
#   None,
#   None,
#   ['Dystopian Sci-Fi',
#    'Teen Adventure',
#    'Action',
#    'Adventure',
#    'Fantasy',
#    'Sci-Fi',
#    'Thriller'],
#   'https://www.imdb.com/title/tt32558705/?ref_=chtmvm_i_87'],
#  ['Salvable',
#   '2025',
#   '1h 41m',
#   'R',
#   '5.1',
#   ['Crime', 'Drama'],
#   'https://www.imdb.com/title/tt31249107/?ref_=chtmvm_i_88'],
#  ['The Legend of Ochi',
#   '2025',
#   '1h 35m',
#   'PG',
#   '6.3',
#   ['Quest', 'Teen Fantasy', 'Adventure', 'Family', 'Fantasy'],
#   'https://www.imdb.com/title/tt8866456/?ref_=chtmvm_i_89'],
#  ['Kesari Chapter 2: The Untold Story of Jallianwala Bagh',
#   '2025',
#   '2h 13m',
#   None,
#   '8.4',
#   ['Docudrama',
#    'Legal Drama',
#    'Period Drama',
#    'Biography',
#    'Drama',
#    'History'],
#   'https://www.imdb.com/title/tt3562110/?ref_=chtmvm_i_90'],
#  ['Tombstone',
#   '1993',
#   '2h 10m',
#   'R',
#   '7.8',
#   ['Costume Drama',
#    'Docudrama',
#    'Period Drama',
#    'Western Epic',
#    'Biography',
#    'Drama',
#    'History',
#    'Western'],
#   'https://www.imdb.com/title/tt0108358/?ref_=chtmvm_i_91'],
#  ['Kraven the Hunter',
#   '2024',
#   '2h 7m',
#   'R',
#   '5.5',
#   ['One-Person Army Action', 'Superhero', 'Action', 'Adventure', 'Thriller'],
#   'https://www.imdb.com/title/tt8790086/?ref_=chtmvm_i_92'],
#  ['The Commitments',
#   '1991',
#   '1h 58m',
#   'R',
#   '7.6',
#   ['Comedy', 'Drama', 'Music'],
#   'https://www.imdb.com/title/tt0101605/?ref_=chtmvm_i_93'],
#  ['Deadpool & Wolverine',
#   '2024',
#   '2h 8m',
#   'R',
#   '7.6',
#   ['Buddy Comedy',
#    'Dark Comedy',
#    'Raunchy Comedy',
#    'Superhero',
#    'Action',
#    'Adventure',
#    'Comedy',
#    'Sci-Fi'],
#   'https://www.imdb.com/title/tt6263850/?ref_=chtmvm_i_94'],
#  ['The Dark Knight',
#   '2008',
#   '2h 32m',
#   'PG-13',
#   '9.0',
#   ['Action Epic',
#    'Epic',
#    'Superhero',
#    'Tragedy',
#    'Action',
#    'Crime',
#    'Drama',
#    'Thriller'],
#   'https://www.imdb.com/title/tt0468569/?ref_=chtmvm_i_95'],
#  ['Trap',
#   '2024',
#   '1h 45m',
#   'PG-13',
#   '5.8',
#   ['Psychological Horror',
#    'Psychological Thriller',
#    'Serial Killer',
#    'Crime',
#    'Horror',
#    'Mystery',
#    'Thriller'],
#   'https://www.imdb.com/title/tt26753003/?ref_=chtmvm_i_96'],
#  ['Inception',
#   '2010',
#   '2h 28m',
#   'PG-13',
#   '8.8',
#   ['Action Epic',
#    'Adventure Epic',
#    'Epic',
#    'Psychological Thriller',
#    'Sci-Fi Epic',
#    'Action',
#    'Adventure',
#    'Sci-Fi',
#    'Thriller'],
#   'https://www.imdb.com/title/tt1375666/?ref_=chtmvm_i_97'],
#  ['Karate Kid: Legends',
#   '2025',
#   '1h 58m',
#   None,
#   None,
#   ['Coming-of-Age',
#    'Martial Arts',
#    'Teen Drama',
#    'Action',
#    'Drama',
#    'Family',
#    'Sport'],
#   'https://www.imdb.com/title/tt1674782/?ref_=chtmvm_i_98'],
#  ['Deep Cover',
#   '2025',
#   '1h 49m',
#   'R',
#   None,
#   ['Comedy', 'Crime'],
#   'https://www.imdb.com/title/tt31121295/?ref_=chtmvm_i_99'],
#  ['A Real Pain',
#   '2024',
#   '1h 30m',
#   'R',
#   '7.1',
#   ['Buddy Comedy', 'Comedy', 'Drama'],
#   'https://www.imdb.com/title/tt21823606/?ref_=chtmvm_i_100']]

# %%
imdb_ranking = pd.DataFrame(movie, columns=["Title", "Release Date", "Run Time", "MPAA Film Rating", "Rating", "Genres", "Webpage"])
imdb_ranking
# Out:
#                    Title Release Date Run Time MPAA Film Rating Rating  \
# 0          Thunderbolts*         2025    2h 6m            PG-13    7.7
# 1                Sinners         2025   2h 17m                R    8.1
# 2                  Havoc         2025   1h 47m            TV-MA    5.7
# 3   Another Simple Favor         2025       2h                R    5.3
# 4       The Accountant 2         2025   2h 12m                R    7.1
# ..                   ...          ...      ...              ...    ...
# 95                  Trap         2024   1h 45m            PG-13    5.8
# 96             Inception         2010   2h 28m            PG-13    8.8
# 97   Karate Kid: Legends         2025   1h 58m             None   None
# 98            Deep Cover         2025   1h 49m                R   None
# 99           A Real Pain         2024   1h 30m                R    7.1
#
#                                                Genres  \
# 0   [Political Drama, Superhero, Action, Adventure...
# 1   [Period Drama, Supernatural Horror, Vampire Ho...
# 2   [Conspiracy Thriller, Drug Crime, Gun Fu, Mart...
# 3   [Dark Comedy, Whodunnit, Comedy, Crime, Myster...
# 4   [Whodunnit, Action, Crime, Drama, Mystery, Thr...
# ..                                                ...
# 95  [Psychological Horror, Psychological Thriller,...
# 96  [Action Epic, Adventure Epic, Epic, Psychologi...
# 97  [Coming-of-Age, Martial Arts, Teen Drama, Acti...
# 98                                    [Comedy, Crime]
# 99                      [Buddy Comedy, Comedy, Drama]
#
#                                               Webpage
# 0   https://www.imdb.com/title/tt20969586/?ref_=ch...
# 1   https://www.imdb.com/title/tt31193180/?ref_=ch...
# 2   https://www.imdb.com/title/tt14123284/?ref_=ch...
# 3   https://www.imdb.com/title/tt20214908/?ref_=ch...
# 4   https://www.imdb.com/title/tt7068946/?ref_=cht...
# ..                                                ...
# 95  https://www.imdb.com/title/tt26753003/?ref_=ch...
# 96  https://www.imdb.com/title/tt1375666/?ref_=cht...
# 97  https://www.imdb.com/title/tt1674782/?ref_=cht...
# 98  https://www.imdb.com/title/tt31121295/?ref_=ch...
# 99  https://www.imdb.com/title/tt21823606/?ref_=ch...
#
# [100 rows x 7 columns]

# %%
imdb_ranking_exploded = imdb_ranking.explode('Genres')
imdb_ranking_exploded
# Out:
#             Title Release Date Run Time MPAA Film Rating Rating  \
# 0   Thunderbolts*         2025    2h 6m            PG-13    7.7
# 0   Thunderbolts*         2025    2h 6m            PG-13    7.7
# 0   Thunderbolts*         2025    2h 6m            PG-13    7.7
# 0   Thunderbolts*         2025    2h 6m            PG-13    7.7
# 0   Thunderbolts*         2025    2h 6m            PG-13    7.7
# ..            ...          ...      ...              ...    ...
# 98     Deep Cover         2025   1h 49m                R   None
# 98     Deep Cover         2025   1h 49m                R   None
# 99    A Real Pain         2024   1h 30m                R    7.1
# 99    A Real Pain         2024   1h 30m                R    7.1
# 99    A Real Pain         2024   1h 30m                R    7.1
#
#              Genres                                            Webpage
# 0   Political Drama  https://www.imdb.com/title/tt20969586/?ref_=ch...
# 0         Superhero  https://www.imdb.com/title/tt20969586/?ref_=ch...
# 0            Action  https://www.imdb.com/title/tt20969586/?ref_=ch...
# 0         Adventure  https://www.imdb.com/title/tt20969586/?ref_=ch...
# 0             Crime  https://www.imdb.com/title/tt20969586/?ref_=ch...
# ..              ...                                                ...
# 98           Comedy  https://www.imdb.com/title/tt31121295/?ref_=ch...
# 98            Crime  https://www.imdb.com/title/tt31121295/?ref_=ch...
# 99     Buddy Comedy  https://www.imdb.com/title/tt21823606/?ref_=ch...
# 99           Comedy  https://www.imdb.com/title/tt21823606/?ref_=ch...
# 99            Drama  https://www.imdb.com/title/tt21823606/?ref_=ch...
#
# [518 rows x 7 columns]

# %%
imdb_ranking.to_csv('imdb_ranking.csv', index=False)

# %%
imdb_ranking_exploded.to_csv('imdb_ranking_genres.csv', index=False)
